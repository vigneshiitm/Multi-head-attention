# %% [markdown]
# <a href="https://colab.research.google.com/github/vigneshiitm/Multi-head-attention/blob/main/Multi_head_attention.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout,  Conv2D, Input, Lambda, Flatten, TimeDistributed
from tensorflow.keras.layers import Add, Reshape, MaxPooling2D, Concatenate, Embedding, RepeatVector, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K

import numpy as np
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
#from tensorflow.keras.layers.core import Dense, Dropout, Activation
from keras.utils import np_utils
from keras.engine.topology import Layer
from tensorflow.keras.callbacks import TensorBoard

def MultiHeadsAttModel(l=8*8, d=512, dv=64, dout=512, nv = 8 ):

    v1 = Input(shape = (l, d))
    q1 = Input(shape = (l, d))
    k1 = Input(shape = (l, d))

    v2 = Dense(dv*nv, activation = "relu")(v1)
    q2 = Dense(dv*nv, activation = "relu")(q1)
    k2 = Dense(dv*nv, activation = "relu")(k1)

    v = Reshape([l, nv, dv])(v2)
    q = Reshape([l, nv, dv])(q2)
    k = Reshape([l, nv, dv])(k2)
    att = tf.einsum('baik,baij->bakj',q, k)/np.sqrt(dv)
    #att = Lambda(lambda x: K.batch_dot(x[0],x[1] ,axes=[-1,-1]) / np.sqrt(dv),output_shape=(l, nv, nv))([q,k])# l, nv, nv
    #att = tf.einsum('', q, k)
    att = Lambda(lambda x:  K.softmax(x) , output_shape=(l, nv, nv))(att)
    out = tf.einsum('bajk,baik->baji',att, v)
    #out = Lambda(lambda x: K.batch_dot(x[0], x[1],axes=[2,2]),  output_shape=(l, nv, dv))([att, v])
    out = Reshape([l, d])(out)
    
    out = Add()([out, q1])

    out = Dense(dout, activation = "relu")(out)

    return  Model(inputs=[q1,k1,v1], outputs=out)

class NormL(Layer):

    def __init__(self, **kwargs):
        super(NormL, self).__init__(**kwargs)

    def build(self, input_shape):
        # Create a trainable weight variable for this layer.
        self.a = self.add_weight(name='kernel', 
                                      shape=(1,input_shape[-1]),
                                      initializer='ones',
                                      trainable=True)
        self.b = self.add_weight(name='kernel', 
                                      shape=(1,input_shape[-1]),
                                      initializer='zeros',
                                      trainable=True)
        super(NormL, self).build(input_shape)  # Be sure to call this somewhere!

    def call(self, x):
        eps = 0.000001
        mu = K.mean(x, keepdims=True, axis=-1)
        sigma = K.std(x, keepdims=True, axis=-1)
        ln_out = (x - mu) / (sigma + eps)
        return ln_out*self.a + self.b

    def compute_output_shape(self, input_shape):
        return input_shape
    
if __name__ == '__main__':   

    nb_classes = 10

    # the data, shuffled and split between tran and test sets
    (X_train, y_train), (X_test, y_test) = mnist.load_data()
    print("X_train original shape", X_train.shape)
    print("y_train original shape", y_train.shape)

    X_train = X_train.reshape(60000, 28,28,1)
    X_test = X_test.reshape(10000, 28,28,1)
    X_train = X_train.astype('float32')
    X_test = X_test.astype('float32')
    X_train /= 255
    X_test /= 255
    print("Training matrix shape", X_train.shape)
    print("Testing matrix shape", X_test.shape)

    Y_train = np_utils.to_categorical(y_train, nb_classes)
    Y_test = np_utils.to_categorical(y_test, nb_classes)
    
    inp = Input(shape = (28,28,1))
    x = Conv2D(32,(2,2),activation='relu', padding='same')(inp)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Conv2D(64,(2,2),activation='relu')(x)
    x = MaxPooling2D(pool_size=(2, 2), padding='same')(x)
    x = Conv2D(64*3,(2,2),activation='relu')(x)
    
    if True:
        x = Reshape([6*6,64*3])(x)    
        att = MultiHeadsAttModel(l=6*6, d=64*3 , dv=8*3, dout=32, nv = 8 )
        x = att([x,x,x])
        x = Reshape([6,6,32])(x)   
        #x = NormL()(x)
        x = BatchNormalization()(x)
    
    x = Flatten()(x) 
    x = Dense(256, activation='relu')(x)
    x = Dense(10, activation='softmax')(x)

    model = Model(inputs=inp, outputs=x)
    print(model.summary())
    model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])
    
    tbCallBack = TensorBoard(log_dir='./Graph/mhatt1', histogram_freq=0, write_graph=True, write_images=True)
    
    model.fit(X_train, Y_train,
              batch_size=128, 
              epochs=100,
              verbose=1,          
              validation_data=(X_test, Y_test),
              callbacks=[tbCallBack]
             )
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# X_train original shape (60000, 28, 28)
# y_train original shape (60000,)
# Training matrix shape (60000, 28, 28, 1)
# Testing matrix shape (10000, 28, 28, 1)
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 28, 28, 32)   160         input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 14, 14, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 13, 13, 64)   8256        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 7, 7, 64)     0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 6, 6, 192)    49344       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 36, 192)      0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# model (Functional)              (None, 36, 32)       117344      reshape[0][0]
#                                                                  reshape[0][0]
#                                                                  reshape[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 6, 6, 32)     0           model[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 6, 6, 32)     128         reshape_5[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1152)         0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 256)          295168      flatten[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 10)           2570        dense_4[0][0]
# ==================================================================================================
# Total params: 472,970
# Trainable params: 472,906
# Non-trainable params: 64
# __________________________________________________________________________________________________
# None
# Epoch 1/100
# 469/469 [==============================] - 14s 14ms/step - loss: 0.2568 - accuracy: 0.9187 - val_loss: 0.0865 - val_accuracy: 0.9807
# Epoch 2/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0390 - accuracy: 0.9884 - val_loss: 0.0401 - val_accuracy: 0.9866
# Epoch 3/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0232 - accuracy: 0.9925 - val_loss: 0.0350 - val_accuracy: 0.9895
# Epoch 4/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0181 - accuracy: 0.9943 - val_loss: 0.0967 - val_accuracy: 0.9713
# Epoch 5/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0168 - accuracy: 0.9944 - val_loss: 0.0672 - val_accuracy: 0.9807
# Epoch 6/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0119 - accuracy: 0.9963 - val_loss: 0.0418 - val_accuracy: 0.9871
# Epoch 7/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0103 - accuracy: 0.9969 - val_loss: 0.0393 - val_accuracy: 0.9885
# Epoch 8/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0097 - accuracy: 0.9965 - val_loss: 0.0596 - val_accuracy: 0.9841
# Epoch 9/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0079 - accuracy: 0.9973 - val_loss: 0.0926 - val_accuracy: 0.9770
# Epoch 10/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0104 - accuracy: 0.9966 - val_loss: 0.0499 - val_accuracy: 0.9882
# Epoch 11/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0055 - accuracy: 0.9980 - val_loss: 0.0422 - val_accuracy: 0.9901
# Epoch 12/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0081 - accuracy: 0.9976 - val_loss: 0.0467 - val_accuracy: 0.9896
# Epoch 13/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0056 - accuracy: 0.9982 - val_loss: 0.0705 - val_accuracy: 0.9858
# Epoch 14/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.0485 - val_accuracy: 0.9897
# Epoch 15/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0062 - accuracy: 0.9979 - val_loss: 0.0386 - val_accuracy: 0.9919
# Epoch 16/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0032 - accuracy: 0.9989 - val_loss: 0.0796 - val_accuracy: 0.9836
# Epoch 17/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.0548 - val_accuracy: 0.9901
# Epoch 18/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.0427 - val_accuracy: 0.9919
# Epoch 19/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0679 - val_accuracy: 0.9882
# Epoch 20/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0105 - accuracy: 0.9973 - val_loss: 0.0864 - val_accuracy: 0.9849
# Epoch 21/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.0911 - val_accuracy: 0.9838
# Epoch 22/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0048 - accuracy: 0.9986 - val_loss: 0.0589 - val_accuracy: 0.9888
# Epoch 23/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.0432 - val_accuracy: 0.9920
# Epoch 24/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.0413 - val_accuracy: 0.9918
# Epoch 25/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0510 - val_accuracy: 0.9911
# Epoch 26/100
# 469/469 [==============================] - 6s 13ms/step - loss: 0.0049 - accuracy: 0.9987 - val_loss: 0.0495 - val_accuracy: 0.9914
# Epoch 27/100
# 469/469 [==============================] - 6s 13ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0446 - val_accuracy: 0.9927
# Epoch 28/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0649 - val_accuracy: 0.9895
# Epoch 29/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0038 - accuracy: 0.9988 - val_loss: 0.0490 - val_accuracy: 0.9912
# Epoch 30/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0488 - val_accuracy: 0.9915
# Epoch 31/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.0507 - val_accuracy: 0.9912
# Epoch 32/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0479 - val_accuracy: 0.9915
# Epoch 33/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0593 - val_accuracy: 0.9898
# Epoch 34/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.0550 - val_accuracy: 0.9898
# Epoch 35/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.0672 - val_accuracy: 0.9886
# Epoch 36/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.0427 - val_accuracy: 0.9925
# Epoch 37/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0409 - val_accuracy: 0.9926
# Epoch 38/100
# 469/469 [==============================] - 6s 12ms/step - loss: 4.1084e-04 - accuracy: 0.9999 - val_loss: 0.0424 - val_accuracy: 0.9922
# Epoch 39/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0565 - val_accuracy: 0.9908
# Epoch 40/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0031 - accuracy: 0.9988 - val_loss: 0.0577 - val_accuracy: 0.9907
# Epoch 41/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0036 - accuracy: 0.9987 - val_loss: 0.0548 - val_accuracy: 0.9907
# Epoch 42/100
# 469/469 [==============================] - 6s 12ms/step - loss: 5.3500e-04 - accuracy: 0.9999 - val_loss: 0.0584 - val_accuracy: 0.9916
# Epoch 43/100
# 469/469 [==============================] - 6s 12ms/step - loss: 4.3226e-04 - accuracy: 0.9999 - val_loss: 0.0606 - val_accuracy: 0.9905
# Epoch 44/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0019 - accuracy: 0.9993 - val_loss: 0.0623 - val_accuracy: 0.9914
# Epoch 45/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0723 - val_accuracy: 0.9882
# Epoch 46/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.0630 - val_accuracy: 0.9921
# Epoch 47/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0514 - val_accuracy: 0.9916
# Epoch 48/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0612 - val_accuracy: 0.9911
# Epoch 49/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0497 - val_accuracy: 0.9933
# Epoch 50/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0528 - val_accuracy: 0.9916
# Epoch 51/100
# 469/469 [==============================] - 6s 12ms/step - loss: 4.4366e-04 - accuracy: 0.9998 - val_loss: 0.0595 - val_accuracy: 0.9916
# Epoch 52/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0717 - val_accuracy: 0.9894
# Epoch 53/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.0683 - val_accuracy: 0.9906
# Epoch 54/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0843 - val_accuracy: 0.9896
# Epoch 55/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0610 - val_accuracy: 0.9919
# Epoch 56/100
# 469/469 [==============================] - 6s 12ms/step - loss: 2.8284e-04 - accuracy: 0.9999 - val_loss: 0.0616 - val_accuracy: 0.9917
# Epoch 57/100
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.0719 - val_accuracy: 0.9915
# Epoch 58/100
# 303/469 [==================>...........] - ETA: 1s - loss: 0.0016 - accuracy: 0.9996
